# %%
#Importing requirede libraries

import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
#Importing Dataset required

df = pd.read_csv("insurance_data.csv")
df.head()
# Out:
#    age  bought_insurance
# 0   22                 0
# 1   25                 0
# 2   47                 1
# 3   52                 0
# 4   46                 1

# %%
#Ploting the dataset

plt.scatter(df.age,df.bought_insurance,marker='+',color='red')

# %%
#Spliting the training Values usijg sklearn

from sklearn.model_selection import train_test_split

# %%
#Defining the Training and Testing Variables

X_train, X_test, y_train, y_test = train_test_split(df[['age']],df.bought_insurance,train_size=0.8)

# %%
X_test
# Out:
#     age
# 6    55
# 10   18
# 26   23
# 8    62
# 11   28
# 25   54

# %%
#Using Logistic Regression Algorithmn

from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
#Fitting the model

model.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
X_test
# Out:
#     age
# 15   55
# 19   18
# 14   49
# 16   25
# 21   26
# 3    52

# %%
#Predicting the Y

y_predicted = model.predict(X_test)

# %%
model.predict_proba(X_test)
# Out:
# array([[0.04551034, 0.95448966],
#        [0.94255777, 0.05744223],
#        [0.88168516, 0.11831484],
#        [0.01554573, 0.98445427],
#        [0.77191465, 0.22808535],
#        [0.05288148, 0.94711852]])

# %%
#Testing model

model.score(X_test,y_test)
# Out:
# 0.6666666666666666

# %%
y_predicted
# Out:
# array([1, 0, 0, 1, 0, 1])

# %%
X_test
# Out:
#     age
# 6    55
# 10   18
# 26   23
# 8    62
# 11   28
# 25   54

# %%
model.coef_
# Out:
# array([[0.15786635]])

# %%
model.intercept_
# Out:
# array([-5.6394118])

# %%
import math
def sigmoid(x):
  return 1 / (1 + math.exp(-x))

# %%
def prediction_function(age):
    z = 0.042 * age - 1.53 # 0.04150133 ~ 0.042 and -1.52726963 ~ -1.53
    y = sigmoid(z)
    return y

# %%
age = 35
prediction_function(age)
# Out:
# 0.4850044983805899

# %%
age = 43
prediction_function(age)
# Out:
# 0.568565299077705

# %%
#0.485 is more than 0.5 which means person with 43 will buy the insurance
